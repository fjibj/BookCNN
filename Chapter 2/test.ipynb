# %%
import logging
import math
import random
import mxnet as mx # 导入 MXNet 库
import numpy as np # 导入 NumPy 库，这是 Python 常用的科学计算库
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\h5py\__init__.py:72: UserWarning: h5py is running against HDF5 1.10.2 when it was built against 1.10.3, this may cause problems
#   '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)

# %%
logging.getLogger().setLevel(logging.DEBUG) # 打开调试信息的显示

# %%
n_sample = 1000 # 训练用的数据点个数
batch_size = 1 # 批大小
learning_rate = 0.1 # 学习速率
n_epoch = 1 # 训练 epoch 数

# %%
# 每个数据点是在 (0,1) 之间的 2 个随机数
train_in = [[ random.uniform(0, 1) for c in range(2)] for n in range(n_sample)] 

train_out = [0 for n in range(n_sample)] # 期望输出，先初始化为 0

for i in range(n_sample):
    # 每个数据点的期望输出是 2 个输入数中的大者
    train_out[i] = max(train_in[i][0], train_in[i][1])

# %%
train_iter = mx.io.NDArrayIter(data = np.array(train_in), label = {'reg_label':np.array(train_out)}, batch_size = batch_size, shuffle = True)

# %%
src = mx.sym.Variable('data')

# %%
fc  = mx.sym.FullyConnected(data = src, num_hidden = 1, name = 'fc')

# %%
net = mx.sym.LinearRegressionOutput(data = fc, name = 'reg')

# %%
module = mx.mod.Module(symbol = net, label_names = (['reg_label']))

# %%
def epoch_callback(epoch, symbol, arg_params, aux_params):
    for k in arg_params: # 对于所有参数…
        print(k) # 输出参数名
        print(arg_params[k].asnumpy()) # 参数值，转为 NumPy 数组，输出更美观

# %%
module.fit(
    train_iter, # 训练数据的迭代器
    eval_data = None, # 在此只训练，不使用测试数据
    eval_metric = mx.metric.create('mse'), # 输出 MSE 损失信息
    optimizer = 'sgd', # 梯度下降算法为 SGD
    # 设置学习速率
    optimizer_params = {'learning_rate': learning_rate}, 
    num_epoch = n_epoch, # 训练 epoch 数
    # 每经过 100 个 batch 输出训练速度 
    batch_end_callback = mx.callback.Speedometer(batch_size, 100), 
    epoch_end_callback = epoch_callback, # 完成每个 epoch 后调用 epoch_callback
)
# Out:
# WARNING:root:Already bound, ignoring bind()
# WARNING:root:optimizer already initialized, ignoring...
# INFO:root:Epoch[0] Batch [0-100]	Speed: 415.19 samples/sec	mse=239471050496981920.000000
# INFO:root:Epoch[0] Batch [100-200]	Speed: 427.61 samples/sec	mse=239710036126817312.000000
# INFO:root:Epoch[0] Batch [200-300]	Speed: 422.20 samples/sec	mse=240400861312940128.000000
# INFO:root:Epoch[0] Batch [300-400]	Speed: 408.42 samples/sec	mse=241933476861124288.000000
# INFO:root:Epoch[0] Batch [400-500]	Speed: 429.45 samples/sec	mse=243625719892730176.000000
# INFO:root:Epoch[0] Batch [500-600]	Speed: 425.80 samples/sec	mse=244724264453190464.000000
# INFO:root:Epoch[0] Batch [600-700]	Speed: 429.45 samples/sec	mse=244740326221361984.000000
# INFO:root:Epoch[0] Batch [700-800]	Speed: 448.71 samples/sec	mse=243666471419295840.000000
# INFO:root:Epoch[0] Batch [800-900]	Speed: 442.75 samples/sec	mse=241980870556857472.000000
# INFO:root:Epoch[0] Train-mse=242243574072076640.000000
# INFO:root:Epoch[0] Time cost=2.355
# fc_weight
# [[0.00097627 0.00185689]]
# fc_bias
# [-1.8965368e+08]

# %%
import logging
import math
import random
import mxnet as mx # 导入 MXNet 库
import numpy as np # 导入 NumPy 库，这是 Python 常用的科学计算库

logging.getLogger().setLevel(logging.DEBUG) # 打开调试信息的显示
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\h5py\__init__.py:72: UserWarning: h5py is running against HDF5 1.10.2 when it was built against 1.10.3, this may cause problems
#   '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)

# %%
n_sample = 10000 # 训练用的数据点个数
batch_size = 10 # 批大小
learning_rate = 0.1 # 学习速率
n_epoch = 10 # 训练 epoch 数

# %%
# 每个数据点是在 (0,1) 之间的 2 个随机数
train_in = [[ random.uniform(0, 1) for c in range(2)] for n in range(n_sample)] 

train_out = [0 for n in range(n_sample)] # 期望输出，先初始化为 0

for i in range(n_sample):
    # 每个数据点的期望输出是 2 个输入数中的大者
    train_out[i] = max(train_in[i][0], train_in[i][1])

# %%
train_iter = mx.io.NDArrayIter(data = np.array(train_in), label = {'reg_label':np.array(train_out)}, batch_size = batch_size, shuffle = True)

# %%
src = mx.sym.Variable('data') # 输入层
fc1  = mx.sym.FullyConnected(data = src, num_hidden = 10, name = 'fc1') # 全连接层
act1 = mx.sym.Activation(data = fc1, act_type = "relu", name = 'act1') # ReLU层
fc2  = mx.sym.FullyConnected(data = act1, num_hidden = 10, name = 'fc2') # 全连接层
act2 = mx.sym.Activation(data = fc2, act_type = "relu", name = 'act2') # ReLU层
fc3  = mx.sym.FullyConnected(data = act2, num_hidden = 1, name = 'fc3') # 全连接层
net = mx.sym.LinearRegressionOutput(data = fc3, name = 'reg') # 输出层

# %%
module = mx.mod.Module(symbol = net, label_names = (['reg_label']))

# %%
module.fit(
    train_iter, # 训练数据的迭代器
    eval_data = None, # 在此只训练，不使用测试数据
    eval_metric = mx.metric.create('mse'), # 输出 MSE 损失信息
    # 将权重和偏置初始化为在[-0.5, 0.5]间均匀的随机数 
    initializer = mx.initializer.Uniform(0.5), 
    optimizer = 'sgd', # 梯度下降算法为 SGD
    # 设置学习速率
    optimizer_params = {'learning_rate': learning_rate}, 
    num_epoch = n_epoch, # 训练 epoch 数
    batch_end_callback = None, # 减少输出信息
    epoch_end_callback = None # 减少输出信息
)
# Out:
# INFO:root:Epoch[0] Train-mse=0.007800
# INFO:root:Epoch[0] Time cost=0.849
# INFO:root:Epoch[1] Train-mse=0.000110
# INFO:root:Epoch[1] Time cost=0.797
# INFO:root:Epoch[2] Train-mse=0.000037
# INFO:root:Epoch[2] Time cost=0.797
# INFO:root:Epoch[3] Train-mse=0.000026
# INFO:root:Epoch[3] Time cost=0.829
# INFO:root:Epoch[4] Train-mse=0.000019
# INFO:root:Epoch[4] Time cost=0.785
# INFO:root:Epoch[5] Train-mse=0.000015
# INFO:root:Epoch[5] Time cost=0.795
# INFO:root:Epoch[6] Train-mse=0.000012
# INFO:root:Epoch[6] Time cost=0.807
# INFO:root:Epoch[7] Train-mse=0.000010
# INFO:root:Epoch[7] Time cost=0.801
# INFO:root:Epoch[8] Train-mse=0.000008
# INFO:root:Epoch[8] Time cost=0.823
# INFO:root:Epoch[9] Train-mse=0.000006
# INFO:root:Epoch[9] Time cost=0.828

# %%
for k in module.get_params(): # 对于所有参数…
    print(k) # 输出参数
# Out:
# {'fc1_weight':
# [[-0.00911304  0.16806103]
#  [ 0.27388623  0.48842368]
#  [-0.00266395  0.46944273]
#  [ 0.0273802   0.45074788]
#  [-0.08957846  0.06337827]
#  [ 0.24851763 -0.12788016]
#  [-0.0624128  -0.20246539]
#  [ 0.6771619  -0.6444324 ]
#  [ 0.24198084 -0.28728324]
#  [-0.11655849 -0.02233487]]
# <NDArray 10x2 @cpu(0)>, 'fc1_bias':
# [ 0.0033334   0.04503838  0.00149323  0.0166809   0.10588984  0.12391525
#   0.         -0.01183207 -0.20605113  0.        ]
# <NDArray 10 @cpu(0)>, 'fc2_weight':
# [[ 0.31828198  0.37886834  0.08965356  0.03288674  0.07664911 -0.11464198
#    0.42559665  0.41582778 -0.38703018 -0.16260383]
#  [-0.40546942  0.17339551 -0.4669742  -0.11407124  0.3519527   0.47252107
#    0.27815676 -0.42885613  0.3522543   0.37008727]
#  [ 0.50763845  0.04610702  0.36522734  0.35847804 -0.02928569  0.01220857
#    0.2805292   0.26652718 -0.33595562  0.22063267]
#  [ 0.13639453  0.07361265 -0.38473454  0.01196705  0.44076538  0.2855435
#    0.02184832 -0.45018482 -0.10159151 -0.02639958]
#  [-0.21817987 -0.2726655   0.31653646  0.27820268 -0.02838671 -0.29420406
#    0.06843394 -0.36513016 -0.4811649  -0.175859  ]
#  [-0.07676022  0.51281273  0.23363806  0.44766    -0.48860434 -0.37017462
#   -0.19766742  0.54722947 -0.33885208 -0.263911  ]
#  [-0.35642365  0.0692202  -0.23047042 -0.03494117 -0.17516735  0.22356327
#   -0.10323253  0.5848558   0.09575771  0.3463109 ]
#  [-0.08080548 -0.18672648  0.18521953  0.02454817 -0.29554775 -0.05654711
#    0.37811744 -0.2704228  -0.4726124   0.03441393]
#  [ 0.20756957  0.50764495  0.00231547  0.03118445  0.07084459 -0.0790553
#   -0.35961306  0.5480836  -0.24382196  0.27838922]
#  [ 0.32001254  0.2649679   0.51057386  0.3426036  -0.17181174 -0.4069308
#    0.19232261  0.10121554  0.4109072   0.36502028]]
# <NDArray 10x10 @cpu(0)>, 'fc2_bias':
# [ 0.00304165  0.17170168 -0.00240075  0.15873697  0.04970604  0.03992675
#   0.03041948  0.          0.01121235  0.04707462]
# <NDArray 10 @cpu(0)>, 'fc3_weight':
# [[ 0.33535904 -0.45453748  0.36043033 -0.4248782   0.18898143  0.28000152
#    0.53251964  0.4025985   0.4514625   0.3762023 ]]
# <NDArray 1x10 @cpu(0)>, 'fc3_bias':
# [0.20747362]
# <NDArray 1 @cpu(0)>}
# {}
